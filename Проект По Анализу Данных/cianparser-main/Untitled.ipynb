# %%
pip install cianparser

# %%
import cianparser
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location="Москва",
    rooms=4,
    start_page=1,
    end_page=15,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=False,
    is_by_homeowner=True,
)
print(data)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# C:\Users\sergo\andan_2023\cianparser-main\cian_parsing_result_sale_1_15_moskva_14_May_2023_16_17_58_923533.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=1&offer_type=flat&deal_type=sale&room4=1&with_neighbors=0&is_by_homeowner=1
#
# Collecting information from pages with list of announcements
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 7 %. Average price: 49 734 285 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 14 %. Average price: 47 989 899 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 20 %. Average price: 50 478 421 rub
#  4 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 112. Progress ratio: 27 %. Average price: 52 095 333 rub
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 140. Progress ratio: 34 %. Average price: 49 625 480 rub
#  6 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 168. Progress ratio: 40 %. Average price: 48 339 269 rub
#  7 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 196. Progress ratio: 47 %. Average price: 47 844 624 rub
#  8 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 224. Progress ratio: 54 %. Average price: 46 616 456 rub
#  9 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 252. Progress ratio: 60 %. Average price: 47 128 173 rub
#  10 | 10 page with list: [=>] 100% | Count of all parsed: 253. Progress ratio: 1687 %. Average price: 47 040 315 rub
#
# The collection of information from the pages with list of announcements is completed
# Total number of parced announcements: 253. Average price: 47 040 315 rub
#
# [{'author': 'ID 103037811', 'author_type': 'homeowner', 'link': 'https://www.cian.ru/sale/flat/287320938/', 'city': 'Москва', 'deal_type': 'sale', 'accommodation_type': 'flat', 'floor': 7, 'floors_count': 29, 'rooms_count': 4, 'total_meters': 165.0, 'price_per_m2': 363636, 'price': 60000000, 'year_of_construction': 2017, 'living_meters': 100.0, 'kitchen_meters': 30.0, 'phone': '+79850016546', 'district': 'Раменки', 'street': 'Мосфильмовская', 'underground': 'Ломоносовский проспект', 'residential_complex': 'Мосфильмовская'}, {'author': 'ID 95474933', 'author_type': 'homeowner', 'link': 'https://www.cian.ru/sale/flat/285629413/', 'city': 'Москва', 'deal_type': 'sale', 'accommodation_type': 'flat', 'floor': 3, 'floors_count': 6, 'rooms_count': 4, 'total_meters': 147.3, 'price_per_m2': 515953, 'price': 76000000, 'year_of_construction': 2006, 'living_meters': 77.5, 'kitchen_meters': 15.0, 'phone': '+79031055376', 'district': 'Мещанский', 'street': 'Троицкая', 'underground': 'Цветной бульвар', 'residential_complex': ''}, {'author': 'ID 71804782', 'author_type': 'homeowner', 'link': 'https://www.cian.ru/sale/flat/286736409/', 'city': 'Москва', 'deal_type': 'sale', 'accommodation_type': 'flat', 'floor': 7, 'floors_count': 17, 'rooms_count': 4, 'total_meters': 90.0, 'price_per_m2': 227777, 'price': 20500000, 'year_of_construction': 2011, 'living_meters': 60.0, 'kitchen_meters': 25.0, 'phone': '+79858254315', 'district': '', 'street': '', 'underground': 'Коммунарка', 'residential_complex': ''}, {'author': 'ID 98431962', 'author_type': 'homeowner', 'link': 'https://www.cian.ru/sale/flat/282118468/', 'city': 'Москва', 'deal_type': 'sale', 'accommodation_type': 'flat', 'floor': 11, 'floors_count': 24, 'rooms_count': 4, 'total_meters': 128.0, 'price_per_m2': 406250, 'price': 52000000, 'year_of_construction': 2007, 'living_meters': 75.0, 'kitchen_meters': 12.0, 'phone': '+79645649720', 'district': 'Раменки', 'street': 'Раменки', 'underground': 'Мичуринский проспект', 'residential_complex': ''}, {'author': 'ID 189423', 'author_type': 'homeowner', 'link': 'https://www.cian.ru/sale/flat/287186329/', 'city': 'Москва', 'deal_type': 'sale', 'accommodation_type': 'flat', 'floor': 3, 'floors_count': 5, 'rooms_count': 4, 'total_meters': 99.3, 'price_per_m2': 274924, 'price': 27300000, 'year_of_construction': 1958, 'living_meters': 74.8, 'kitchen_meters': 8.2, 'phone': '+79660590996', 'district': 'Текстильщики', 'street': '7-я Текстильщиков', 'underground': 'Волжская', 'residential_complex': ''}, {'author': 'ID 70692059', 'author_type': 'homeowner', 'link': 'https://www.cian.ru/sale/flat/282748028/', 'city': 'Москва', 'deal_type': 'sale', 'accommodation_type': 'flat', 'floor': 8, 'floors_count': 9, 'rooms_count': 4, 'total_meters': 62.7, 'price_per_m2': 234449, 'price': 14700000, 'year_of_construction': 1969, 'living_meters': 46.1, 'kitchen_meters': 6.0, 'phone': '+79629141595', 'district': 'Выхино-Жулебино', 'street': 'Волгоградский проспект', 'underground': 'Юго-Восточная', 'residential_complex': ''}, {'author': 'ID 100747187', 'author_type': 'homeowner', 'link': 'https://www.cian.ru/sale/flat/284703910/', 'city': 'Москва', 'deal_type': 'sale', 'accommodation_type': 'flat', 'floor': 17, 'floors_count': 21, 'rooms_count': 4, 'total_meters': 150.0, 'price_per_m2': 430000, 'price': 64500000, 'year_of_construction': 2015, 'living_meters': 141.1, 'kitchen_meters': -1, 'phone': '+79623688692', 'district': 'Раменки', 'street': 'Мосфильмовская', 'underground': 'Раменки', 'residential_complex': 'Мосфильмовский'}, {'author': 'ID 102611578', 'author_type': 'homeowner', 'link': 'https://www.cian.ru/sale/flat/286873853/', 'city': 'Москва', 'deal_type': 'sale', 'accommodation_type': 'flat', 'floor': 19, 'floors_count': 20, 'rooms_count': 4, 'total_meters': 103.0, 'price_per_m2': 356796, 'price': 36750000, 'year_of_construction': 2010, 'living_meters': 57.0, 'kitchen_meters': 27.5, 'phone': '+79169285912', 'district': 'Обручевский', 'street': 'Академика Волгина',  ...

# %%
import pandas as pd

# %%
new = pd.DataFrame(data)
new
# Out:
#                author        author_type  \
# 0    Аеон-Девелопмент          developer
# 1              Тауэрс          developer
# 2            MR Group          developer
# 3              Пионер          developer
# 4       Sminex-Интеко          developer
# ..                ...                ...
# 972        EstateLiga  real_estate_agent
# 973      Этажи Москва  real_estate_agent
# 974      СЕДЬМОЕ НЕБО  real_estate_agent
# 975      Dream Realty  real_estate_agent
# 976               НДВ  real_estate_agent
#
#                                          link    city deal_type  \
# 0    https://www.cian.ru/sale/flat/274260488/  Москва      sale
# 1    https://www.cian.ru/sale/flat/286264250/  Москва      sale
# 2    https://www.cian.ru/sale/flat/283864406/  Москва      sale
# 3    https://www.cian.ru/sale/flat/283969773/  Москва      sale
# 4    https://www.cian.ru/sale/flat/286944836/  Москва      sale
# ..                                        ...     ...       ...
# 972  https://www.cian.ru/sale/flat/281386654/  Москва      sale
# 973  https://www.cian.ru/sale/flat/286150246/  Москва      sale
# 974  https://www.cian.ru/sale/flat/286055722/  Москва      sale
# 975  https://www.cian.ru/sale/flat/286995179/  Москва      sale
# 976  https://www.cian.ru/sale/flat/276863587/  Москва      sale
#
#     accommodation_type  floor  floors_count  rooms_count  total_meters  \
# 0                 flat     -1            -1           -1         202.0
# 1                 flat     41            66            1          51.2
# 2                 flat     -1            -1           -1         202.0
# 3                 flat     -1            -1           -1         202.0
# 4                 flat      4             6            1          76.6
# ..                 ...    ...           ...          ...           ...
# 972               flat      4             9            1          32.0
# 973               flat      1             9            1          31.7
# 974               flat      9             9            1          32.0
# 975               flat      3            12            1          38.9
# 976               flat      6             9            1          32.0
#
#      price_per_m2      price                                  district  \
# 0          111141   22450632                              Дорогомилово
# 1          854000   43724800                               Пресненский
# 2          103154   20837134                            Филевский парк
# 3           79735   16106665                              Марьина роща
# 4         2436031  186600000                                 Хамовники
# ..            ...        ...                                       ...
# 972        359375   11500000                               Пресненский
# 973        362776   11500000                              Марьина роща
# 974        359375   11500000  Уютная 1-КА в Останкинском е!1-комн. кв.
# 975        303341   11800000                               Теплый Стан
# 976        387500   12400000                               Пресненский
#
#                            street   underground            residential_complex
# 0              Кутузовский проезд          Фили  River Park Towers Кутузовский
# 1    1-й Красногвардейский проезд   Выставочная                    NEVA TOWERS
# 2                                          Фили                   Фили Сити ЖК
# 3                        Полковая   Савёловская                          PRIDE
# 4         3-й Обыденский переулок                                Обыденский №1
# ..                            ...           ...                            ...
# 972             Причальный проезд      Шелепиха
# 973         Старомарьинское шоссе  Марьина роща
# 974                         32 м²
# 975            Академика Бакулева     Тропарёво
# 976             Причальный проезд      Шелепиха
#
# [977 rows x 16 columns]
